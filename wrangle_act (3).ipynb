# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import numpy as np
archive_df = pd.read_csv('twitter-archive-enhanced (1).csv')

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
import requests
import os

folder_name = 'workspace'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

with open(os.path.join(folder_name, url.split('/')[-1]), mode = 'wb') as file:
    file.write(response.content)

# %%
image_df = pd.read_csv('workspace/image-predictions.tsv', sep = '\t')

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %% [markdown]
# #### I used the details of a senior colleague's consumer_key, consumer_secret, access_token and access_secret because I was not able to get access to mine in time in order to submit my project early.

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'zTy3uMuVxaRMi4w2NEELYhTHV'
consumer_secret = 'SETDDMnlA9IiufPv1nCQ6wg6AXySdZqwlR3KCZumozlPMCTamI'
access_token = '1535948596721360896-aQZb0OlbfQZGNoNOZhXGhIiwUD1duJ'
access_secret = 'cKytOMue6MQr4SSVYf6gaBQOQQdSTlMOlGwkRPPhOwwyQ'

#consumer_key = 'HIDDEN'
#consumer_secret = 'HIDDEN'
#access_token = 'HIDDEN'
#access_secret = 'HIDDEN'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True,
                wait_on_rate_limit_notify=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = archive_df.tweet_id.values
len(tweet_ids)
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
tweet = []
with open ('tweet_json.txt', 'r') as file:
    for line in file:
        tweets = json.loads(line)
        tweet_id = tweets.get('id')
        retweet_count = tweets.get('retweet_count')
        favorite_count = tweets.get('favorite_count')
        tweet.append({'id': tweet_id,
                        'retweet_count': retweet_count,
                        'favorite_count': favorite_count})
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
api_df = pd.DataFrame(tweet, columns = ['id', 'retweet_count', 'favorite_count'])
api_df.to_csv('api_df.csv', index = False)

# %%
api_df = pd.read_csv('api_df.csv')

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment and programmatic assessement to assess the data.
#
# **Note:** Pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %%
archive_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# Missing data noticed. Dog stages should be identified in one column.

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# Wrong datatypes and missing values noticed.

# %%
archive_df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %% [markdown]
# Odd values of rating denominator noticed

# %%
archive_df.shape
# Out:
# (2356, 17)

# %%
image_df.shape
# Out:
# (2075, 12)

# %%
image_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_df.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# p1_conf rounds up to 1, mean value is greater than p2_conf and p3_conf

# %%
image_df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# Dog breed prediction should be unified (based on prediction score in p_conf column)and unnecessary data deleted.

# %%
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2325 entries, 0 to 2324
# Data columns (total 3 columns):
# id                2325 non-null int64
# retweet_count     2325 non-null int64
# favorite_count    2325 non-null int64
# dtypes: int64(3)
# memory usage: 54.6 KB

# %%
api_df.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           6934           33282
# 1  892177421306343426           5240           28806
# 2  891815181378084864           3453           21660
# 3  891689557279858688           7156           36295
# 4  891327558926688256           7679           34696

# %%
api_df.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  2.325000e+03    2325.000000     2325.000000
# mean   7.416926e+17    2448.378925     6945.715699
# std    6.814903e+16    4142.784568    10787.775558
# min    6.660209e+17       0.000000        0.000000
# 25%    6.780233e+17     492.000000     1207.000000
# 50%    7.177900e+17    1139.000000     3005.000000
# 75%    7.986285e+17    2834.000000     8472.000000
# max    8.924206e+17   69908.000000   142856.000000

# %%
api_df.shape
# Out:
# (2325, 3)

# %% [markdown]
# ### Quality & Tidiness issues
# 1. Correct datatypes for archive_df (Quality Issue)
#
# 2. Merge doggo, floofer, pupper and puppo columns in archive_df (Tidiness Issue)
#
# 3. Rearrange column order in archive_df (Quality Issue)
#
# 4. Correct rating_numerator and rating_denominator columns in archive_df (Quality Issue)
#
# 5. Examine irregularities in rating denominator in archive_df (Quality Issue)
#
# 6. Remove retweets in archive_df (Quality Issue)
#
# 7. Some tweets are not dogs in image_df (Quality Issue)
#
# 8. Create unified row for dog breed prediction in image_df (Tidiness Issue)
#
# 9. Drop redundant columns in archive_df and image_df (Quality Issue)
#
# 10. Correct name column in archive_df (Quality Issue)
#
# 11. Rename the id column in api_df to tweet_id to be able to merge (Quality Issue)
#
# 12. Merge the 3 datasets on tweet_id column (Tidiness Issue)

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
archive = archive_df.copy()
image = image_df.copy()
api = api_df.copy()

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Correct datatypes for archive_df

# %% [markdown]
# #### Code:

# %%
#Convert archive_df 'timestamp' column datatype to datetime
archive['timestamp'] = pd.to_datetime(archive['timestamp'])

# %% [markdown]
# #### Test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Merge doggo, floofer, pupper and puppo columns in archive_df

# %% [markdown]
# #### Code:

# %%
#First, change 'None' values of 'doggo', 'floofer', 'pupper', 'puppo' columns to NaN
for i in range(len(archive)):
    for j in [13,14,15,16]:
        if archive.iloc[i,j] == 'None':
            archive.iloc[i,j] = np.nan
#Merge columns
archive['dog_stage'] = archive[['doggo', 'floofer', 'pupper', 'puppo']].apply(lambda x: ', '.join(x.dropna()), axis=1)
#Set empty cells of 'dog_stage' to NaN
archive['dog_stage'] = archive['dog_stage'].replace('', np.NaN)

# %% [markdown]
# #### Test:

# %%
archive.head()
# Out:
#        name            tweet_id           timestamp  \
# 0   Phineas  892420643555336193 2017-08-01 16:23:56
# 1     Tilly  892177421306343426 2017-08-01 00:17:27
# 2    Archie  891815181378084864 2017-07-31 00:18:03
# 3     Darla  891689557279858688 2017-07-30 15:58:51
# 4  Franklin  891327558926688256 2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %%
archive['dog_stage'].value_counts()
# Out:
# pupper            245
# doggo              83
# puppo              29
# doggo, pupper      12
# floofer             9
# doggo, puppo        1
# doggo, floofer      1
# Name: dog_stage, dtype: int64

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Rearrange column order in archive_df

# %% [markdown]
# #### Code:

# %%
#Get column order
column_order = archive.columns.tolist()
column_order
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo',
#  'dog_stage']

# %%
#Rearrange 
column_order = [column_order[12]] + column_order[:12] + column_order[13:]
archive = archive[column_order]

# %% [markdown]
# #### Test:

# %%
archive.head()
# Out:
#        name            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   Phineas  892420643555336193                    NaN                  NaN
# 1     Tilly  892177421306343426                    NaN                  NaN
# 2    Archie  891815181378084864                    NaN                  NaN
# 3     Darla  891689557279858688                    NaN                  NaN
# 4  Franklin  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### Issue #4:

# %% [markdown]
# #### Correct rating_numerator and rating_denominator columns in archive_df

# %% [markdown]
# #### Code:

# %%
import re 

regex = r'''([+-]?([0-9]+[.])?[0-9]+\/[+-]?([0-9]+[.])?[0-9]+)'''

def get_pattern(pat):
  try:
      return re.findall(regex, pat)[0][0]
  except Exception as e:
      return ''


archive['pattern'] = archive['text'].apply(get_pattern)
archive['fraction'] = archive['rating_numerator'].astype(str) + '/' + archive['rating_denominator'].astype(str)
archive[archive['pattern'] != archive['fraction']][['pattern', 'fraction']]
# Out:
#        pattern fraction
# 45     13.5/10     5/10
# 313     960/00    960/0
# 340    9.75/10    75/10
# 387     007/10     7/10
# 695    9.75/10    75/10
# 763   11.27/10    27/10
# 1689    9.5/10     5/10
# 1712  11.26/10    26/10
# 2260     -5/10     5/10

# %%
archive = archive[archive['pattern'] == archive['fraction']]

# %% [markdown]
# #### Test:

# %%
archive.head()
# Out:
#        name            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   Phineas  892420643555336193                    NaN                  NaN
# 1     Tilly  892177421306343426                    NaN                  NaN
# 2    Archie  891815181378084864                    NaN                  NaN
# 3     Darla  891689557279858688                    NaN                  NaN
# 4  Franklin  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
archive[archive['pattern'] != archive['fraction']]
# Out:
# Empty DataFrame
# Columns: [name, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, doggo, floofer, pupper, puppo, dog_stage, pattern, fraction]
# Index: []

# %% [markdown]
# ### Issue #5:

# %% [markdown]
# #### Examine irregularities in rating denominator in archive_df (Quality Issue)

# %% [markdown]
# #### Code:

# %%
archive['rating_denominator'].value_counts()
# Out:
# 10     2325
# 50        3
# 11        3
# 80        2
# 20        2
# 15        1
# 16        1
# 40        1
# 70        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 2         1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# To have a good evaluation of the rating each dog received, there has to be a rating meter. We set this meter to 10 which is the most frequent denominator

# %%
archive[archive['rating_denominator'] != 10]
# Out:
#           name            tweet_id  in_reply_to_status_id  \
# 342       None  832088576586297345           8.320875e+17
# 433       None  820690176645140481                    NaN
# 516        Sam  810984652412424192                    NaN
# 784       None  775096608509886464                    NaN
# 902       None  758467244762497024                    NaN
# 1068      None  740373189193256964                    NaN
# 1120      this  731156023742988288                    NaN
# 1165      None  722974582966214656                    NaN
# 1202  Bluebert  716439118184652801                    NaN
# 1228      None  713900603437621249                    NaN
# 1254      None  710658690886586372                    NaN
# 1274      None  709198395643068416                    NaN
# 1351         a  704054845121142784                    NaN
# 1433      None  697463031882764288                    NaN
# 1598      None  686035780142297088           6.860340e+17
# ...

# %% [markdown]
# Sample examination showed that the ratings were extracted erroneously, suggesting lack of data integrity for ratings that don't have their denominators as 10

# %%
archive = archive[archive['rating_denominator'] == 10]

# %% [markdown]
# #### Test:

# %%
archive['rating_denominator'].value_counts()
# Out:
# 10    2325
# Name: rating_denominator, dtype: int64

# %% [markdown]
# ### Issue #6:

# %% [markdown]
# #### Remove retweets in archive_df

# %% [markdown]
# #### Code:

# %%
#Check rows with values for 'retweeted_status_id' column
archive[archive['retweeted_status_id'].notna()]
# Out:
#           name            tweet_id  in_reply_to_status_id  \
# 19      Canela  888202515573088257                    NaN
# 32        None  886054160059072513                    NaN
# 36       Lilly  885311592912609280                    NaN
# 68        Emmy  879130579576475649                    NaN
# 73      Shadow  878404777348136964                    NaN
# 74    Terrance  878316110768087041                    NaN
# 78        None  877611172832227328                    NaN
# 91        Coco  874434818259525634                    NaN
# 95      Walter  873697596434513921                    NaN
# 97      Sierra  873337748698140672                    NaN
# 101       None  872668790621863937                    NaN
# 109       Dawn  871166179821445120                    NaN
# 118      quite  869988702071779329                    NaN
# 124     Cooper  868639477480148993                    NaN
# 130       None  867072653475098625                    NaN
# ...

# %%
#Drop rows with NaN for 'retweeted_status_id' column
archive = archive[archive['retweeted_status_id'].isnull()]

# %%
#Drop rows with NaN for 'in_reply_to_status_id' column
archive = archive[archive['in_reply_to_status_id'].isnull()]

# %% [markdown]
# #### Test:

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2076 entries, 0 to 2355
# Data columns (total 20 columns):
# name                          2076 non-null object
# tweet_id                      2076 non-null int64
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2076 non-null datetime64[ns]
# source                        2076 non-null object
# text                          2076 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2073 non-null object
# rating_numerator              2076 non-null int64
# rating_denominator            2076 non-null int64
# doggo                         83 non-null object
# floofer                       10 non-null object
# pupper                        229 non-null object
# ...

# %% [markdown]
# ### Issue #7:

# %% [markdown]
# #### Some tweets are not dogs in image_df

# %% [markdown]
# #### Code:

# %%
image[(image['p1_dog'] == False)&(image['p2_dog'] == False)&(image['p3_dog'] == False)]
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 29    666411507551481857    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 45    666786068205871104    https://pbs.twimg.com/media/CUDmZIkWcAAIPPe.jpg
# 50    666837028449972224    https://pbs.twimg.com/media/CUEUva1WsAA2jPb.jpg
# 51    666983947667116034    https://pbs.twimg.com/media/CUGaXDhW4AY9JUH.jpg
# 53    667012601033924608    https://pbs.twimg.com/media/CUG0bC0U8AAw2su.jpg
# 56    667065535570550784    https://pbs.twimg.com/media/CUHkkJpXIAA2w3n.jpg
# ...

# %%
#Drop rows whose predictions are not dog breeds
index_false = image[(image['p1_dog'] == False)&(image['p2_dog'] == False)&(image['p3_dog'] == False)].index
image.drop(index_false, inplace = True)

# %% [markdown]
# #### Test:

# %%
image[(image['p1_dog'] == False)&(image['p2_dog'] == False)&(image['p3_dog'] == False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %% [markdown]
# ### Issue #8:

# %% [markdown]
# #### Create unified row for dog breed prediction in image_df

# %% [markdown]
# #### Code:

# %%
image[image['p1_dog'] == False]
# Out:
#                 tweet_id                                            jpg_url  \
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 22    666337882303524864    https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 33    666430724426358785    https://pbs.twimg.com/media/CT-jNYqW4AAPi2M.jpg
# 43    666776908487630848    https://pbs.twimg.com/media/CUDeDoWUYAAD-EM.jpg
# 52    666996132027977728    https://pbs.twimg.com/media/CUGlb6iUwAITEbW.jpg
# 87    667524857454854144    https://pbs.twimg.com/media/CUOGUfJW4AA_eni.jpg
# 95    667550904950915073    https://pbs.twimg.com/media/CUOb_gUUkAACXdS.jpg
# 103   667806454573760512    https://pbs.twimg.com/media/CUSGbXeVAAAgztZ.jpg
# 108   667878741721415682    https://pbs.twimg.com/media/CUTILFiWcAE8Rle.jpg
# 113   667915453470232577    https://pbs.twimg.com/media/CUTpj-GWcAATc6A.jpg
# 126   668256321989451776    https://pbs.twimg.com/media/CUYflCXWEAAzQVu.jpg
# ...

# %%
#First, change 'p1', 'p2' and 'p3' values to NaN if any of 'p1_dog', 'p2_dog' and 'p3_dog' columns respectively is False
for i in range(len(image)):
    for j in [5,8,11]:
        if image.iloc[i,j] == False:
            image.iloc[i,j-2] = 0

#Merge columns 'p1', 'p2' and 'p3' into 1 ('p1')
for k in range(len(image)):
    if image.iloc[k,3] == 0:
        if image.iloc[k,6] != 0:
            image.iloc[k,3] = image.iloc[k,6]
        elif image.iloc[k,9] != 0:
            image.iloc[k,3] = image.iloc[k,9]

# %% [markdown]
# #### Test:

# %%
image[image['p1_dog'] == False]
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ### Issue #9:

# %% [markdown]
# #### Drop redundant columns in archive_df and image_df

# %% [markdown]
# #### Code:

# %%
archive.head()
# Out:
#        name            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   Phineas  892420643555336193                    NaN                  NaN
# 1     Tilly  892177421306343426                    NaN                  NaN
# 2    Archie  891815181378084864                    NaN                  NaN
# 3     Darla  891689557279858688                    NaN                  NaN
# 4  Franklin  891327558926688256                    NaN                  NaN
#
#             timestamp                                             source  \
# 0 2017-08-01 16:23:56  <a href="http://twitter.com/download/iphone" r...
# 1 2017-08-01 00:17:27  <a href="http://twitter.com/download/iphone" r...
# 2 2017-07-31 00:18:03  <a href="http://twitter.com/download/iphone" r...
# 3 2017-07-30 15:58:51  <a href="http://twitter.com/download/iphone" r...
# 4 2017-07-29 16:00:24  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
#Delete 'in_reply_to_status_id', 'in_reply_to_user_id', 'retweeted_status_id', 'retweeted_status_user_id', 
#'retweeted_status_timestamp', 'doggo', 'floofer', 'pupper' and 'puppo' columns, they are no longer needed.
archive.drop(archive.iloc[:, [2,3,7,8,9,13,14,15,16,18,19]], axis = 1, inplace = True)

# %%
image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#Drop columns 'p1_conf', 'p1_dog', 'p2, 'p2_conf', 'p2_dog', 'p3', 'p3_conf' and 'p3_dog' columns, they are no longer needed.
image.drop(image.iloc[:, 4:], axis = 1, inplace = True)

# %% [markdown]
# #### Test:

# %%
archive.head()
# Out:
#        name            tweet_id           timestamp  \
# 0   Phineas  892420643555336193 2017-08-01 16:23:56
# 1     Tilly  892177421306343426 2017-08-01 00:17:27
# 2    Archie  891815181378084864 2017-07-31 00:18:03
# 3     Darla  891689557279858688 2017-07-30 15:58:51
# 4  Franklin  891327558926688256 2017-07-29 16:00:24
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %%
image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1
# 0        1  Welsh_springer_spaniel
# 1        1                 redbone
# 2        1         German_shepherd
# 3        1     Rhodesian_ridgeback
# 4        1      miniature_pinscher

# %% [markdown]
# ### Issue #10:

# %% [markdown]
# #### Correct name column in archive_df

# %%
archive['name'].value_counts()
# Out:
# None         591
# a             54
# Lucy          11
# Charlie       11
# Oliver        10
# Cooper        10
# Penny          9
# Tucker         9
# the            8
# Winston        8
# Sadie          8
# Lola           8
# Daisy          7
# Toby           7
# Jax            6
# Stanley        6
# Bailey         6
# Koda           6
# Bo             6
# Oscar          6
# Dave           5
# an             5
# Rusty          5
# Buddy          5
# Bella          5
# Leo            5
# Louis          5
# Scout          5
# Milo           5
# Chester        5
#             ...
# Siba           1
# Baloo          1
# Snickers       1
# Crumpet        1
# BeBe           1
# Tedders        1
# Josep          1
# Dot            1
# Jersey         1
# Sky            1
# Ziva           1
# Leonard        1
# Herb           1
# Stephanus      1
# Nollie         1
# Sid            1
# Stewie         1
# Harper         1
# Chuq           1
# Monty          1
# Shaggy         1
# ...

# %% [markdown]
# Observe carefully all lowercase names are invalid

# %%
archive['name'] = archive['name'].str.replace('^[a-z]+', 'None')

# %% [markdown]
# #### Test:

# %%
archive['name'].value_counts()
# Out:
# None         692
# Charlie       11
# Lucy          11
# Cooper        10
# Oliver        10
# Penny          9
# Tucker         9
# Sadie          8
# Winston        8
# Lola           8
# Daisy          7
# Toby           7
# Jax            6
# Bo             6
# Oscar          6
# Stanley        6
# Koda           6
# Bailey         6
# Scout          5
# Rusty          5
# Dave           5
# Buddy          5
# Leo            5
# Milo           5
# Louis          5
# Bentley        5
# Bella          5
# Chester        5
# Alfie          4
# Larry          4
#             ...
# Siba           1
# Baloo          1
# Snickers       1
# Crumpet        1
# Dylan          1
# BeBe           1
# Toffee         1
# Tedders        1
# Chuq           1
# Sky            1
# Ziva           1
# Leonard        1
# Herb           1
# Stephanus      1
# Nollie         1
# Sid            1
# Stewie         1
# Harper         1
# Monty          1
# Shawwn         1
# Shaggy         1
# ...

# %% [markdown]
# ### Issue #11:

# %% [markdown]
# #### Rename the id column in api_df to tweet_id to be able to merge

# %% [markdown]
# #### Code:

# %%
api.rename(columns = {'id' : 'tweet_id'}, inplace = True)

# %% [markdown]
# #### Test:

# %%
api.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           6934           33282
# 1  892177421306343426           5240           28806
# 2  891815181378084864           3453           21660
# 3  891689557279858688           7156           36295
# 4  891327558926688256           7679           34696

# %% [markdown]
# ### Issue #12:

# %% [markdown]
# #### Merge archive_df, image_df and api_df based on column 'tweet_id'

# %% [markdown]
# #### Code:

# %%
merged_data = pd.merge(archive, image, how = "inner", on = 'tweet_id')
merged_data = pd.merge(merged_data, api, how = "inner", on = 'tweet_id')

# %% [markdown]
# #### Test

# %%
merged_data.head()
# Out:
#        name            tweet_id           timestamp  \
# 0     Tilly  892177421306343426 2017-08-01 00:17:27
# 1    Archie  891815181378084864 2017-07-31 00:18:03
# 2     Darla  891689557279858688 2017-07-30 15:58:51
# 3  Franklin  891327558926688256 2017-07-29 16:00:24
# 4      None  891087950875897856 2017-07-29 00:08:17
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Tilly. She's just checking pup on you....
# 1  This is Archie. He is a rare Norwegian Pouncin...
# 2  This is Darla. She commenced a snooze mid meal...
# 3  This is Franklin. He would like you to stop ca...
# 4  Here we have a majestic great white breaching ...
#
# ...

# %% [markdown]
# #### Notice that rows with unmatched 'tweet_id' are deleted

# %% [markdown]
# #### Check for duplicates

# %%
merged_data.duplicated(subset = ['tweet_id']).sum()
# Out:
# 0

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
merged_data.to_csv('twitter_archive_master.csv', index = False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %%
df.head()
# Out:
#        name            tweet_id            timestamp  \
# 0     Tilly  892177421306343426  2017-08-01 00:17:27
# 1    Archie  891815181378084864  2017-07-31 00:18:03
# 2     Darla  891689557279858688  2017-07-30 15:58:51
# 3  Franklin  891327558926688256  2017-07-29 16:00:24
# 4      None  891087950875897856  2017-07-29 00:08:17
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Tilly. She's just checking pup on you....
# 1  This is Archie. He is a rare Norwegian Pouncin...
# 2  This is Darla. She commenced a snooze mid meal...
# 3  This is Franklin. He would like you to stop ca...
# ...

# %%
df.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator      img_num  \
# count  1.638000e+03       1638.000000              1638.0  1638.000000
# mean   7.393385e+17         10.817460                10.0     1.215507
# std    6.806968e+16          1.777897                 0.0     0.575899
# min    6.660209e+17          0.000000                10.0     1.000000
# 25%    6.773183e+17         10.000000                10.0     1.000000
# 50%    7.138403e+17         11.000000                10.0     1.000000
# 75%    7.931921e+17         12.000000                10.0     1.000000
# max    8.921774e+17         14.000000                10.0     4.000000
#
#        retweet_count  favorite_count
# count    1638.000000     1638.000000
# mean     2267.515873     7905.004884
# std      4136.396314    11655.559254
# min        11.000000       64.000000
# 25%       510.000000     1776.250000
# 50%      1122.000000     3682.500000
# 75%      2574.750000     9775.750000
# ...

# %%
#Most common dog
df['p1'].value_counts()
# Out:
# golden_retriever                  152
# Labrador_retriever                100
# Pembroke                           94
# Chihuahua                          89
# pug                                62
# toy_poodle                         49
# chow                               47
# Samoyed                            41
# Pomeranian                         40
# malamute                           33
# Chesapeake_Bay_retriever           31
# French_bulldog                     30
# cocker_spaniel                     30
# miniature_pinscher                 24
# Eskimo_dog                         22
# German_shepherd                    21
# Cardigan                           21
# Shih-Tzu                           20
# beagle                             20
# Staffordshire_bullterrier          19
# Siberian_husky                     19
# Rottweiler                         18
# Shetland_sheepdog                  18
# Maltese_dog                        18
# basset                             17
# ...

# %%
#Breed with most rating greater than mean
df['p1'][df['rating_numerator'] >= df['rating_numerator'].mean()].value_counts()
# Out:
# golden_retriever              122
# Pembroke                       78
# Labrador_retriever             70
# Chihuahua                      48
# chow                           37
# toy_poodle                     35
# Samoyed                        35
# Pomeranian                     28
# pug                            25
# cocker_spaniel                 22
# French_bulldog                 20
# malamute                       19
# Chesapeake_Bay_retriever       15
# Cardigan                       15
# Eskimo_dog                     15
# Siberian_husky                 14
# miniature_pinscher             13
# Rottweiler                     12
# basset                         12
# German_shepherd                12
# Staffordshire_bullterrier      11
# Great_Pyrenees                 11
# kuvasz                         11
# vizsla                         10
# kelpie                         10
# Shih-Tzu                       10
# Pekinese                        9
# ...

# %%
#Breed with highest retweets
df['p1'][df['retweet_count'] == df['retweet_count'].max()].value_counts()
# Out:
# Labrador_retriever    1
# Name: p1, dtype: int64

# %%
#Breed with highest likes
df['p1'][df['favorite_count'] == df['favorite_count'].max()].value_counts()
# Out:
# Labrador_retriever    1
# Name: p1, dtype: int64

# %%
#Breed with highest retweets and likes
df[df['retweet_count'] == df['retweet_count'].max()]
# Out:
#      name            tweet_id            timestamp  \
# 673  None  744234799360020481  2016-06-18 18:26:18
#
#                                                 source  \
# 673  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  \
# 673  Here's a doggo realizing you can stand in a po...
#
#                                          expanded_urls  rating_numerator  \
# 673  https://twitter.com/dog_rates/status/744234799...                13
#
#      rating_denominator dog_stage  \
# 673                  10     doggo
#
#                                                jpg_url  img_num  \
# 673  https://pbs.twimg.com/ext_tw_video_thumb/74423...        1
#
#                      p1  retweet_count  favorite_count
# 673  Labrador_retriever          69908          142856

# %%
#Breed with lowest rating
df[['p1', 'rating_numerator']].set_index('p1').nsmallest(10, ['rating_numerator'])
# Out:
#                                 rating_numerator
# p1
# American_Staffordshire_terrier                 0
# Maltese_dog                                    2
# miniature_pinscher                             2
# Afghan_hound                                   3
# Chihuahua                                      3
# Dandie_Dinmont                                 3
# soft-coated_wheaten_terrier                    3
# pug                                            3
# Pembroke                                       4
# kuvasz                                         4

# %%
df[df['p1'] == 'American_Staffordshire_terrier'].describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator    img_num  \
# count  1.500000e+01         15.000000                15.0  15.000000
# mean   7.545525e+17         10.133333                10.0   1.200000
# std    6.893052e+16          3.090693                 0.0   0.560612
# min    6.685423e+17          0.000000                10.0   1.000000
# 25%    6.890325e+17         10.000000                10.0   1.000000
# 50%    7.388850e+17         11.000000                10.0   1.000000
# 75%    8.239820e+17         11.500000                10.0   1.000000
# max    8.471162e+17         13.000000                10.0   3.000000
#
#        retweet_count  favorite_count
# count      15.000000       15.000000
# mean     1635.933333     7075.533333
# std      1059.019322     6261.655097
# min       178.000000      399.000000
# 25%       850.500000     2551.500000
# 50%      1304.000000     4948.000000
# 75%      2770.500000    10204.500000
# max      3269.000000    20650.000000

# %%
df[df['p1'] == 'Maltese_dog'].describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator    img_num  \
# count  1.800000e+01         18.000000                18.0  18.000000
# mean   6.882493e+17          9.777778                10.0   1.277778
# std    2.080871e+16          2.129776                 0.0   0.460889
# min    6.668268e+17          2.000000                10.0   1.000000
# 25%    6.759462e+17         10.000000                10.0   1.000000
# 50%    6.789501e+17         10.000000                10.0   1.000000
# 75%    6.941588e+17         10.750000                10.0   1.750000
# max    7.349123e+17         12.000000                10.0   2.000000
#
#        retweet_count  favorite_count
# count      18.000000       18.000000
# mean     1030.166667     2572.111111
# std      1209.679260     2190.277175
# min        78.000000      218.000000
# 25%       481.500000     1602.000000
# 50%       735.500000     2104.500000
# 75%       989.000000     2767.500000
# max      5453.000000    10292.000000

# %%
df[df['p1'] == 'miniature_pinscher'].describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator    img_num  \
# count  2.400000e+01         24.000000                24.0  24.000000
# mean   7.318021e+17         10.041667                10.0   1.291667
# std    6.576371e+16          2.612331                 0.0   0.690253
# min    6.660492e+17          2.000000                10.0   1.000000
# 25%    6.724810e+17          9.750000                10.0   1.000000
# 50%    7.125994e+17         11.000000                10.0   1.000000
# 75%    7.869781e+17         12.000000                10.0   1.000000
# max    8.800958e+17         12.000000                10.0   4.000000
#
#        retweet_count  favorite_count
# count      24.000000       24.000000
# mean     1850.083333     6922.416667
# std      2115.766321     8224.927048
# min        36.000000       88.000000
# 25%       337.250000     1458.750000
# 50%      1085.000000     3138.500000
# 75%      2400.500000     8519.000000
# max      8733.000000    28829.000000

# %%
#Breed with lowest mean rating
df.groupby('p1').mean().nsmallest(10, ['rating_numerator'])
# Out:
#                                  tweet_id  rating_numerator  \
# p1
# Japanese_spaniel             6.773010e+17          5.000000
# soft-coated_wheaten_terrier  7.056062e+17          8.166667
# Scotch_terrier               6.892838e+17          9.000000
# Walker_hound                 7.333173e+17          9.000000
# Ibizan_hound                 6.844888e+17          9.250000
# Tibetan_terrier              6.973258e+17          9.250000
# dalmatian                    7.154213e+17          9.333333
# Boston_bull                  7.286202e+17          9.416667
# Welsh_springer_spaniel       7.318789e+17          9.500000
# Dandie_Dinmont               7.195659e+17          9.571429
#
#                              rating_denominator   img_num  retweet_count  \
# p1
# Japanese_spaniel                           10.0  1.000000     352.000000
# soft-coated_wheaten_terrier                10.0  1.083333     836.083333
# Scotch_terrier                             10.0  1.000000     993.000000
# ...

# %% [markdown]
# ### Insights:
# 1. Mean dog rating is 12/10
#
# 2. The most common dog is the Golden Retriever
#
# 3. Breed mostly rated high (mean rating and higher) is the Golden Retriever
#
# 4. Breed with the highest likes is the Labrador Retriever
#
# 5. Some dogs had really low ratings

# %% [markdown]
# ### Visualization

# %%
df['p1'].value_counts()[:5].plot(kind = 'bar', figsize = (5,4));

# %% [markdown]
# #### Golden Retriever is most common breed

# %%
df['p1'][df['rating_numerator'] >= df['rating_numerator'].mean()].value_counts()[:5].plot(kind = 'bar', figsize = (5,4));

# %% [markdown]
# #### Golden Retriever is the most highly rated breed

# %%
df[['p1', 'retweet_count']].set_index('p1').nlargest(5, ['retweet_count']).plot(kind = 'bar', figsize = (5,4));

# %% [markdown]
# #### Breed with the highest retweets is the Labrador Retriever

# %%
df[['p1', 'favorite_count']].set_index('p1').nlargest(5, ['favorite_count']).plot(kind = 'bar', figsize = (5,4));

# %% [markdown]
# #### Breed with the highest likes is the Labrador Retriever

# %%
df[['p1', 'rating_numerator']].set_index('p1').nsmallest(4, ['rating_numerator']).plot(kind = 'bar', figsize = (5,4));

# %% [markdown]
# #### The breed with lowest rating score is the American Straffordshire Terrier

# %% [markdown]
# #### I got a lot of help wrangling my data from Stackoverflow, Geeksforgeeks, Dataquest, Towardsdatascience, Marsja and Pandas documentation
